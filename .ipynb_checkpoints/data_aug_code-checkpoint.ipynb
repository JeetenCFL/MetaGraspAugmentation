# %%
# Import the required libraries
import cv2
import json
import matplotlib.pyplot as plt
import matplotlib.image as mat_img
import numpy as np
import pandas as pd
import os
import csv
import pandas as pd
import random
import albumentations as A
from numpyencoder import NumpyEncoder
from skimage.color import label2rgb
from pandas.io.json import json_normalize
from detectron2.structures import polygons_to_bitmask
# %matplotlib inline

# %%
# uncomment the unzip line when only when requrired
# !unzip metagraspnetdifficulty1-easy.zip
# !mv difficulty-1-coco-label.json meta-grasp/ -t originalMetaGrasp/
# Out:
# Archive:  metagraspnetdifficulty1-easy.zip
#   inflating: difficulty-1-coco-label.json
#   inflating: meta-grasp/scene10000/0_camera_params.json
#   inflating: meta-grasp/scene10000/0_depth.png
#   inflating: meta-grasp/scene10000/0_order.csv
#   inflating: meta-grasp/scene10000/0_rgb.png
#   inflating: meta-grasp/scene10000/1_camera_params.json
#   inflating: meta-grasp/scene10000/1_depth.png
#   inflating: meta-grasp/scene10000/1_order.csv
#   inflating: meta-grasp/scene10000/1_rgb.png
#   inflating: meta-grasp/scene10000/2_camera_params.json
#   inflating: meta-grasp/scene10000/2_depth.png
#   inflating: meta-grasp/scene10000/2_order.csv
#   inflating: meta-grasp/scene10000/2_rgb.png
#   inflating: meta-grasp/scene10000/3_camera_params.json
#   inflating: meta-grasp/scene10000/3_depth.png
#   inflating: meta-grasp/scene10000/3_order.csv
#   inflating: meta-grasp/scene10000/3_rgb.png
#   inflating: meta-grasp/scene10000/4_camera_params.json
#   inflating: meta-grasp/scene10000/4_depth.png
#   inflating: meta-grasp/scene10000/4_order.csv
#   inflating: meta-grasp/scene10000/4_rgb.png
#   inflating: meta-grasp/scene10000/5_camera_params.json
#   inflating: meta-grasp/scene10000/5_depth.png
#   inflating: meta-grasp/scene10000/5_order.csv
#   inflating: meta-grasp/scene10000/5_rgb.png
#   inflating: meta-grasp/scene10000/6_camera_params.json
#   inflating: meta-grasp/scene10000/6_depth.png
#   inflating: meta-grasp/scene10000/6_order.csv
#   inflating: meta-grasp/scene10000/6_rgb.png
#   inflating: meta-grasp/scene10000/7_camera_params.json
#   inflating: meta-grasp/scene10000/7_depth.png
#   inflating: meta-grasp/scene10000/7_order.csv
#   inflating: meta-grasp/scene10000/7_rgb.png
#   inflating: meta-grasp/scene10000/8_camera_params.json
#   inflating: meta-grasp/scene10000/8_depth.png
#   inflating: meta-grasp/scene10000/8_order.csv
#   inflating: meta-grasp/scene10000/8_rgb.png
#   inflating: meta-grasp/scene10001/0_camera_params.json
#   inflating: meta-grasp/scene10001/0_depth.png
#   inflating: meta-grasp/scene10001/0_order.csv
#   inflating: meta-grasp/scene10001/0_rgb.png
#   inflating: meta-grasp/scene10001/1_camera_params.json
#   inflating: meta-grasp/scene10001/1_depth.png
#   inflating: meta-grasp/scene10001/1_order.csv
#   inflating: meta-grasp/scene10001/1_rgb.png
#   inflating: meta-grasp/scene10001/2_camera_params.json
#   inflating: meta-grasp/scene10001/2_depth.png
#   inflating: meta-grasp/scene10001/2_order.csv
#   inflating: meta-grasp/scene10001/2_rgb.png
#   inflating: meta-grasp/scene10001/3_camera_params.json
#   inflating: meta-grasp/scene10001/3_depth.png
#   inflating: meta-grasp/scene10001/3_order.csv
#   inflating: meta-grasp/scene10001/3_rgb.png
#   inflating: meta-grasp/scene10001/4_camera_params.json
#   inflating: meta-grasp/scene10001/4_depth.png
#   inflating: meta-grasp/scene10001/4_order.csv
#   inflating: meta-grasp/scene10001/4_rgb.png
#   inflating: meta-grasp/scene10001/5_camera_params.json
#   inflating: meta-grasp/scene10001/5_depth.png
#   inflating: meta-grasp/scene10001/5_order.csv
#   inflating: meta-grasp/scene10001/5_rgb.png
#   inflating: meta-grasp/scene10001/6_camera_params.json
#   inflating: meta-grasp/scene10001/6_depth.png
#   inflating: meta-grasp/scene10001/6_order.csv
#   inflating: meta-grasp/scene10001/6_rgb.png
#   inflating: meta-grasp/scene10001/7_camera_params.json
#   inflating: meta-grasp/scene10001/7_depth.png
#   inflating: meta-grasp/scene10001/7_order.csv
#   inflating: meta-grasp/scene10001/7_rgb.png
#   inflating: meta-grasp/scene10001/8_camera_params.json
#   inflating: meta-grasp/scene10001/8_depth.png
#   inflating: meta-grasp/scene10001/8_order.csv
#   inflating: meta-grasp/scene10001/8_rgb.png
#   inflating: meta-grasp/scene10002/0_camera_params.json
#   inflating: meta-grasp/scene10002/0_depth.png
#   inflating: meta-grasp/scene10002/0_order.csv
#   inflating: meta-grasp/scene10002/0_rgb.png
#   inflating: meta-grasp/scene10002/1_camera_params.json
#   inflating: meta-grasp/scene10002/1_depth.png
#   inflating: meta-grasp/scene10002/1_order.csv
#   inflating: meta-grasp/scene10002/1_rgb.png
#   inflating: meta-grasp/scene10002/2_camera_params.json
#   inflating: meta-grasp/scene10002/2_depth.png
#   inflating: meta-grasp/scene10002/2_order.csv
#   inflating: meta-grasp/scene10002/2_rgb.png
#   inflating: meta-grasp/scene10002/3_camera_params.json
#   inflating: meta-grasp/scene10002/3_depth.png
#   inflating: meta-grasp/scene10002/3_order.csv
#   inflating: meta-grasp/scene10002/3_rgb.png
#   inflating: meta-grasp/scene10002/4_camera_params.json
#   inflating: meta-grasp/scene10002/4_depth.png
#   inflating: meta-grasp/scene10002/4_order.csv
#   inflating: meta-grasp/scene10002/4_rgb.png
#   inflating: meta-grasp/scene10002/5_camera_params.json
#   inflating: meta-grasp/scene10002/5_depth.png
#   inflating: meta-grasp/scene10002/5_order.csv
#   inflating: meta-grasp/scene10002/5_rgb.png
#   inflating: meta-grasp/scene10002/6_camera_params.json
#   inflating: meta-grasp/scene10002/6_depth.png
#   inflating: meta-grasp/scene10002/6_order.csv
#   inflating: meta-grasp/scene10002/6_rgb.png
#   inflating: meta-grasp/scene10002/7_camera_params.json
#   inflating: meta-grasp/scene10002/7_depth.png
#   inflating: meta-grasp/scene10002/7_order.csv
#   inflating: meta-grasp/scene10002/7_rgb.png
#   inflating: meta-grasp/scene10002/8_camera_params.json
#   inflating: meta-grasp/scene10002/8_depth.png
#   inflating: meta-grasp/scene10002/8_order.csv
#   inflating: meta-grasp/scene10002/8_rgb.png
#   inflating: meta-grasp/scene10003/0_camera_params.json
#   inflating: meta-grasp/scene10003/0_depth.png
#   inflating: meta-grasp/scene10003/0_order.csv
#   inflating: meta-grasp/scene10003/0_rgb.png
#   inflating: meta-grasp/scene10003/1_camera_params.json
#   inflating: meta-grasp/scene10003/1_depth.png
#   inflating: meta-grasp/scene10003/1_order.csv
#   inflating: meta-grasp/scene10003/1_rgb.png
#   inflating: meta-grasp/scene10003/2_camera_params.json
#   inflating: meta-grasp/scene10003/2_depth.png
#   inflating: meta-grasp/scene10003/2_order.csv
#   inflating: meta-grasp/scene10003/2_rgb.png
#   inflating: meta-grasp/scene10003/3_camera_params.json
#   inflating: meta-grasp/scene10003/3_depth.png
#   inflating: meta-grasp/scene10003/3_order.csv
#   inflating: meta-grasp/scene10003/3_rgb.png
#   inflating: meta-grasp/scene10003/4_camera_params.json
#   inflating: meta-grasp/scene10003/4_depth.png
#   inflating: meta-grasp/scene10003/4_order.csv
#   inflating: meta-grasp/scene10003/4_rgb.png
#   inflating: meta-grasp/scene10003/5_camera_params.json
#   inflating: meta-grasp/scene10003/5_depth.png
#   inflating: meta-grasp/scene10003/5_order.csv
#   inflating: meta-grasp/scene10003/5_rgb.png
#   inflating: meta-grasp/scene10003/6_camera_params.json
#   inflating: meta-grasp/scene10003/6_depth.png
#   inflating: meta-grasp/scene10003/6_order.csv
#   inflating: meta-grasp/scene10003/6_rgb.png
#   inflating: meta-grasp/scene10003/7_camera_params.json
#   inflating: meta-grasp/scene10003/7_depth.png
#   inflating: meta-grasp/scene10003/7_order.csv
#   inflating: meta-grasp/scene10003/7_rgb.png
#   inflating: meta-grasp/scene10003/8_camera_params.json
#   inflating: meta-grasp/scene10003/8_depth.png
#   inflating: meta-grasp/scene10003/8_order.csv
#   inflating: meta-grasp/scene10003/8_rgb.png
#   inflating: meta-grasp/scene10004/0_camera_params.json
#   inflating: meta-grasp/scene10004/0_depth.png
#   inflating: meta-grasp/scene10004/0_order.csv
#   inflating: meta-grasp/scene10004/0_rgb.png
#   inflating: meta-grasp/scene10004/1_camera_params.json
#   inflating: meta-grasp/scene10004/1_depth.png
#   inflating: meta-grasp/scene10004/1_order.csv
#   inflating: meta-grasp/scene10004/1_rgb.png
#   inflating: meta-grasp/scene10004/2_camera_params.json
#   inflating: meta-grasp/scene10004/2_depth.png
#   inflating: meta-grasp/scene10004/2_order.csv
#   inflating: meta-grasp/scene10004/2_rgb.png
#   inflating: meta-grasp/scene10004/3_camera_params.json
#   inflating: meta-grasp/scene10004/3_depth.png
#   inflating: meta-grasp/scene10004/3_order.csv
#   inflating: meta-grasp/scene10004/3_rgb.png
#   inflating: meta-grasp/scene10004/4_camera_params.json
#   inflating: meta-grasp/scene10004/4_depth.png
#   inflating: meta-grasp/scene10004/4_order.csv
#   inflating: meta-grasp/scene10004/4_rgb.png
#   inflating: meta-grasp/scene10004/5_camera_params.json
#   inflating: meta-grasp/scene10004/5_depth.png
#   inflating: meta-grasp/scene10004/5_order.csv
#   inflating: meta-grasp/scene10004/5_rgb.png
#   inflating: meta-grasp/scene10004/6_camera_params.json
#   inflating: meta-grasp/scene10004/6_depth.png
#   inflating: meta-grasp/scene10004/6_order.csv
#   inflating: meta-grasp/scene10004/6_rgb.png
#   inflating: meta-grasp/scene10004/7_camera_params.json
#   inflating: meta-grasp/scene10004/7_depth.png
#   inflating: meta-grasp/scene10004/7_order.csv
#   inflating: meta-grasp/scene10004/7_rgb.png
#   inflating: meta-grasp/scene10004/8_camera_params.json
#   inflating: meta-grasp/scene10004/8_depth.png
#   inflating: meta-grasp/scene10004/8_order.csv
#   inflating: meta-grasp/scene10004/8_rgb.png
#   inflating: meta-grasp/scene10005/0_camera_params.json
#   inflating: meta-grasp/scene10005/0_depth.png
#   inflating: meta-grasp/scene10005/0_order.csv
#   inflating: meta-grasp/scene10005/0_rgb.png
#   inflating: meta-grasp/scene10005/1_camera_params.json
#   inflating: meta-grasp/scene10005/1_depth.png
#   inflating: meta-grasp/scene10005/1_order.csv
#   inflating: meta-grasp/scene10005/1_rgb.png
#   inflating: meta-grasp/scene10005/2_camera_params.json
#   inflating: meta-grasp/scene10005/2_depth.png
#   inflating: meta-grasp/scene10005/2_order.csv
#   inflating: meta-grasp/scene10005/2_rgb.png
#   inflating: meta-grasp/scene10005/3_camera_params.json
#   inflating: meta-grasp/scene10005/3_depth.png
#   inflating: meta-grasp/scene10005/3_order.csv
#   inflating: meta-grasp/scene10005/3_rgb.png
#   inflating: meta-grasp/scene10005/4_camera_params.json
#   inflating: meta-grasp/scene10005/4_depth.png
#   inflating: meta-grasp/scene10005/4_order.csv
#   inflating: meta-grasp/scene10005/4_rgb.png
#   inflating: meta-grasp/scene10005/5_camera_params.json
#   inflating: meta-grasp/scene10005/5_depth.png
#   inflating: meta-grasp/scene10005/5_order.csv
#   inflating: meta-grasp/scene10005/5_rgb.png
#   inflating: meta-grasp/scene10005/6_camera_params.json
#   inflating: meta-grasp/scene10005/6_depth.png
#   inflating: meta-grasp/scene10005/6_order.csv
#   inflating: meta-grasp/scene10005/6_rgb.png
#   inflating: meta-grasp/scene10005/7_camera_params.json
#   inflating: meta-grasp/scene10005/7_depth.png
#   inflating: meta-grasp/scene10005/7_order.csv
#   inflating: meta-grasp/scene10005/7_rgb.png
#   inflating: meta-grasp/scene10005/8_camera_params.json
#   inflating: meta-grasp/scene10005/8_depth.png
#   inflating: meta-grasp/scene10005/8_order.csv
#   inflating: meta-grasp/scene10005/8_rgb.png
#   inflating: meta-grasp/scene10006/0_camera_params.json
#   inflating: meta-grasp/scene10006/0_depth.png
#   inflating: meta-grasp/scene10006/0_order.csv
#   inflating: meta-grasp/scene10006/0_rgb.png
#   inflating: meta-grasp/scene10006/1_camera_params.json
#   inflating: meta-grasp/scene10006/1_depth.png
#   inflating: meta-grasp/scene10006/1_order.csv
#   inflating: meta-grasp/scene10006/1_rgb.png
#   inflating: meta-grasp/scene10006/2_camera_params.json
#   inflating: meta-grasp/scene10006/2_depth.png
#   inflating: meta-grasp/scene10006/2_order.csv
#   inflating: meta-grasp/scene10006/2_rgb.png
#   inflating: meta-grasp/scene10006/3_camera_params.json
#   inflating: meta-grasp/scene10006/3_depth.png
#   inflating: meta-grasp/scene10006/3_order.csv
#   inflating: meta-grasp/scene10006/3_rgb.png
#   inflating: meta-grasp/scene10006/4_camera_params.json
#   inflating: meta-grasp/scene10006/4_depth.png
#   inflating: meta-grasp/scene10006/4_order.csv
#   inflating: meta-grasp/scene10006/4_rgb.png
#   inflating: meta-grasp/scene10006/5_camera_params.json
#   inflating: meta-grasp/scene10006/5_depth.png
#   inflating: meta-grasp/scene10006/5_order.csv
#   inflating: meta-grasp/scene10006/5_rgb.png
#   inflating: meta-grasp/scene10006/6_camera_params.json
#   inflating: meta-grasp/scene10006/6_depth.png
#   inflating: meta-grasp/scene10006/6_order.csv
#   inflating: meta-grasp/scene10006/6_rgb.png
#   inflating: meta-grasp/scene10006/7_camera_params.json
#   inflating: meta-grasp/scene10006/7_depth.png
#   inflating: meta-grasp/scene10006/7_order.csv
#   inflating: meta-grasp/scene10006/7_rgb.png
#   inflating: meta-grasp/scene10006/8_camera_params.json
#   inflating: meta-grasp/scene10006/8_depth.png
#   inflating: meta-grasp/scene10006/8_order.csv
#   inflating: meta-grasp/scene10006/8_rgb.png
#   inflating: meta-grasp/scene10007/0_camera_params.json
#   inflating: meta-grasp/scene10007/0_depth.png
#   inflating: meta-grasp/scene10007/0_order.csv
#   inflating: meta-grasp/scene10007/0_rgb.png
#   inflating: meta-grasp/scene10007/1_camera_params.json
#   inflating: meta-grasp/scene10007/1_depth.png
#   inflating: meta-grasp/scene10007/1_order.csv
#   inflating: meta-grasp/scene10007/1_rgb.png
#   inflating: meta-grasp/scene10007/2_camera_params.json
#   inflating: meta-grasp/scene10007/2_depth.png
#   inflating: meta-grasp/scene10007/2_order.csv
#   inflating: meta-grasp/scene10007/2_rgb.png
#   inflating: meta-grasp/scene10007/3_camera_params.json
#   inflating: meta-grasp/scene10007/3_depth.png
#   inflating: meta-grasp/scene10007/3_order.csv
#   inflating: meta-grasp/scene10007/3_rgb.png
#   inflating: meta-grasp/scene10007/4_camera_params.json
#   inflating: meta-grasp/scene10007/4_depth.png
#   inflating: meta-grasp/scene10007/4_order.csv
#   inflating: meta-grasp/scene10007/4_rgb.png
#   inflating: meta-grasp/scene10007/5_camera_params.json
#   inflating: meta-grasp/scene10007/5_depth.png
#   inflating: meta-grasp/scene10007/5_order.csv
#   inflating: meta-grasp/scene10007/5_rgb.png
#   inflating: meta-grasp/scene10007/6_camera_params.json
#   inflating: meta-grasp/scene10007/6_depth.png
#   inflating: meta-grasp/scene10007/6_order.csv
#   inflating: meta-grasp/scene10007/6_rgb.png
#   inflating: meta-grasp/scene10007/7_camera_params.json
#   inflating: meta-grasp/scene10007/7_depth.png
#   inflating: meta-grasp/scene10007/7_order.csv
#   inflating: meta-grasp/scene10007/7_rgb.png
#   inflating: meta-grasp/scene10007/8_camera_params.json
#   inflating: meta-grasp/scene10007/8_depth.png
#   inflating: meta-grasp/scene10007/8_order.csv
#   inflating: meta-grasp/scene10007/8_rgb.png
#   inflating: meta-grasp/scene10008/1_camera_params.json
#   inflating: meta-grasp/scene10008/1_depth.png
#   inflating: meta-grasp/scene10008/1_order.csv
#   inflating: meta-grasp/scene10008/1_rgb.png
#   inflating: meta-grasp/scene10008/2_camera_params.json
#   inflating: meta-grasp/scene10008/2_depth.png
#   inflating: meta-grasp/scene10008/2_order.csv
#   inflating: meta-grasp/scene10008/2_rgb.png
#   inflating: meta-grasp/scene10008/3_camera_params.json
#   inflating: meta-grasp/scene10008/3_depth.png
#   inflating: meta-grasp/scene10008/3_order.csv
#   inflating: meta-grasp/scene10008/3_rgb.png
#   inflating: meta-grasp/scene10008/4_camera_params.json
#   inflating: meta-grasp/scene10008/4_depth.png
#   inflating: meta-grasp/scene10008/4_order.csv
#   inflating: meta-grasp/scene10008/4_rgb.png
#   inflating: meta-grasp/scene10008/5_camera_params.json
#   inflating: meta-grasp/scene10008/5_depth.png
#   inflating: meta-grasp/scene10008/5_order.csv
#   inflating: meta-grasp/scene10008/5_rgb.png
#   inflating: meta-grasp/scene10008/6_camera_params.json
#   inflating: meta-grasp/scene10008/6_depth.png
#   inflating: meta-grasp/scene10008/6_order.csv
#   inflating: meta-grasp/scene10008/6_rgb.png
#   inflating: meta-grasp/scene10008/7_camera_params.json
#   inflating: meta-grasp/scene10008/7_depth.png
#   inflating: meta-grasp/scene10008/7_order.csv
#   inflating: meta-grasp/scene10008/7_rgb.png
#   inflating: meta-grasp/scene10008/8_camera_params.json
#   inflating: meta-grasp/scene10008/8_depth.png
#   inflating: meta-grasp/scene10008/8_order.csv
#   inflating: meta-grasp/scene10008/8_rgb.png
#   inflating: meta-grasp/scene10009/0_camera_params.json
#   inflating: meta-grasp/scene10009/0_depth.png
#   inflating: meta-grasp/scene10009/0_order.csv
#   inflating: meta-grasp/scene10009/0_rgb.png
#   inflating: meta-grasp/scene10009/1_camera_params.json
#   inflating: meta-grasp/scene10009/1_depth.png
#   inflating: meta-grasp/scene10009/1_order.csv
#   inflating: meta-grasp/scene10009/1_rgb.png
#   inflating: meta-grasp/scene10009/2_camera_params.json
#   inflating: meta-grasp/scene10009/2_depth.png
#   inflating: meta-grasp/scene10009/2_order.csv
#   inflating: meta-grasp/scene10009/2_rgb.png
#   inflating: meta-grasp/scene10009/3_camera_params.json
#   inflating: meta-grasp/scene10009/3_depth.png
#   inflating: meta-grasp/scene10009/3_order.csv
#   inflating: meta-grasp/scene10009/3_rgb.png
#   inflating: meta-grasp/scene10009/4_camera_params.json
#   inflating: meta-grasp/scene10009/4_depth.png
#   inflating: meta-grasp/scene10009/4_order.csv
#   inflating: meta-grasp/scene10009/4_rgb.png
#   inflating: meta-grasp/scene10009/5_camera_params.json
#   inflating: meta-grasp/scene10009/5_depth.png
#   inflating: meta-grasp/scene10009/5_order.csv
#   inflating: meta-grasp/scene10009/5_rgb.png
#   inflating: meta-grasp/scene10009/6_camera_params.json
#   inflating: meta-grasp/scene10009/6_depth.png
#   inflating: meta-grasp/scene10009/6_order.csv
#   inflating: meta-grasp/scene10009/6_rgb.png
#   inflating: meta-grasp/scene10009/7_camera_params.json
#   inflating: meta-grasp/scene10009/7_depth.png
#   inflating: meta-grasp/scene10009/7_order.csv
#   inflating: meta-grasp/scene10009/7_rgb.png
#   inflating: meta-grasp/scene10009/8_camera_params.json
#   inflating: meta-grasp/scene10009/8_depth.png
#   inflating: meta-grasp/scene10009/8_order.csv
#   inflating: meta-grasp/scene10009/8_rgb.png
#   inflating: meta-grasp/scene10010/0_camera_params.json
#   inflating: meta-grasp/scene10010/0_depth.png
#   inflating: meta-grasp/scene10010/0_order.csv
#   inflating: meta-grasp/scene10010/0_rgb.png
#   inflating: meta-grasp/scene10010/1_camera_params.json
#   inflating: meta-grasp/scene10010/1_depth.png
#   inflating: meta-grasp/scene10010/1_order.csv
#   inflating: meta-grasp/scene10010/1_rgb.png
#   inflating: meta-grasp/scene10010/2_camera_params.json
#   inflating: meta-grasp/scene10010/2_depth.png
#   inflating: meta-grasp/scene10010/2_order.csv
#   inflating: meta-grasp/scene10010/2_rgb.png
#   inflating: meta-grasp/scene10010/3_camera_params.json
#   inflating: meta-grasp/scene10010/3_depth.png
#   inflating: meta-grasp/scene10010/3_order.csv
#   inflating: meta-grasp/scene10010/3_rgb.png
#   inflating: meta-grasp/scene10010/4_camera_params.json
#   inflating: meta-grasp/scene10010/4_depth.png
#   inflating: meta-grasp/scene10010/4_order.csv
#   inflating: meta-grasp/scene10010/4_rgb.png
#   inflating: meta-grasp/scene10010/5_camera_params.json
#   inflating: meta-grasp/scene10010/5_depth.png
#   inflating: meta-grasp/scene10010/5_order.csv
#   inflating: meta-grasp/scene10010/5_rgb.png
#   inflating: meta-grasp/scene10010/6_camera_params.json
#   inflating: meta-grasp/scene10010/6_depth.png
#   inflating: meta-grasp/scene10010/6_order.csv
#   inflating: meta-grasp/scene10010/6_rgb.png
#   inflating: meta-grasp/scene10010/7_camera_params.json
#   inflating: meta-grasp/scene10010/7_depth.png
#   inflating: meta-grasp/scene10010/7_order.csv
#   inflating: meta-grasp/scene10010/7_rgb.png
#   inflating: meta-grasp/scene10010/8_camera_params.json
#   inflating: meta-grasp/scene10010/8_depth.png
#   inflating: meta-grasp/scene10010/8_order.csv
#   inflating: meta-grasp/scene10010/8_rgb.png
#   inflating: meta-grasp/scene10011/0_camera_params.json
#   inflating: meta-grasp/scene10011/0_depth.png
#   inflating: meta-grasp/scene10011/0_order.csv
#   inflating: meta-grasp/scene10011/0_rgb.png
#   inflating: meta-grasp/scene10011/1_camera_params.json
#   inflating: meta-grasp/scene10011/1_depth.png
#   inflating: meta-grasp/scene10011/1_order.csv
#   inflating: meta-grasp/scene10011/1_rgb.png
#   inflating: meta-grasp/scene10011/2_camera_params.json
#   inflating: meta-grasp/scene10011/2_depth.png
#   inflating: meta-grasp/scene10011/2_order.csv
#   inflating: meta-grasp/scene10011/2_rgb.png
#   inflating: meta-grasp/scene10011/3_camera_params.json
#   inflating: meta-grasp/scene10011/3_depth.png
#   inflating: meta-grasp/scene10011/3_order.csv
#   inflating: meta-grasp/scene10011/3_rgb.png
#   inflating: meta-grasp/scene10011/4_camera_params.json
#   inflating: meta-grasp/scene10011/4_depth.png
#   inflating: meta-grasp/scene10011/4_order.csv
#   inflating: meta-grasp/scene10011/4_rgb.png
#   inflating: meta-grasp/scene10011/5_camera_params.json
#   inflating: meta-grasp/scene10011/5_depth.png
#   inflating: meta-grasp/scene10011/5_order.csv
#   inflating: meta-grasp/scene10011/5_rgb.png
#   inflating: meta-grasp/scene10011/6_camera_params.json
#   inflating: meta-grasp/scene10011/6_depth.png
#   inflating: meta-grasp/scene10011/6_order.csv
#   inflating: meta-grasp/scene10011/6_rgb.png
#   inflating: meta-grasp/scene10011/7_camera_params.json
#   inflating: meta-grasp/scene10011/7_depth.png
#   inflating: meta-grasp/scene10011/7_order.csv
#   inflating: meta-grasp/scene10011/7_rgb.png
#   inflating: meta-grasp/scene10011/8_camera_params.json
#   inflating: meta-grasp/scene10011/8_depth.png
#   inflating: meta-grasp/scene10011/8_order.csv
#   inflating: meta-grasp/scene10011/8_rgb.png
#   inflating: meta-grasp/scene10012/0_camera_params.json
#   inflating: meta-grasp/scene10012/0_depth.png
#   inflating: meta-grasp/scene10012/0_order.csv
#   inflating: meta-grasp/scene10012/0_rgb.png
#   inflating: meta-grasp/scene10012/1_camera_params.json
#   inflating: meta-grasp/scene10012/1_depth.png
#   inflating: meta-grasp/scene10012/1_order.csv
#   inflating: meta-grasp/scene10012/1_rgb.png
#   inflating: meta-grasp/scene10012/2_camera_params.json
#   inflating: meta-grasp/scene10012/2_depth.png
#   inflating: meta-grasp/scene10012/2_order.csv
#   inflating: meta-grasp/scene10012/2_rgb.png
#   inflating: meta-grasp/scene10012/3_camera_params.json
#   inflating: meta-grasp/scene10012/3_depth.png
#   inflating: meta-grasp/scene10012/3_order.csv
#   inflating: meta-grasp/scene10012/3_rgb.png
#   inflating: meta-grasp/scene10012/4_camera_params.json
#   inflating: meta-grasp/scene10012/4_depth.png
#   inflating: meta-grasp/scene10012/4_order.csv
#   inflating: meta-grasp/scene10012/4_rgb.png
#   inflating: meta-grasp/scene10012/5_camera_params.json
#   inflating: meta-grasp/scene10012/5_depth.png
#   inflating: meta-grasp/scene10012/5_order.csv
#   inflating: meta-grasp/scene10012/5_rgb.png
#   inflating: meta-grasp/scene10012/6_camera_params.json
#   inflating: meta-grasp/scene10012/6_depth.png
#   inflating: meta-grasp/scene10012/6_order.csv
#   inflating: meta-grasp/scene10012/6_rgb.png
#   inflating: meta-grasp/scene10012/7_camera_params.json
#   inflating: meta-grasp/scene10012/7_depth.png
#   inflating: meta-grasp/scene10012/7_order.csv
#   inflating: meta-grasp/scene10012/7_rgb.png
#   inflating: meta-grasp/scene10012/8_camera_params.json
#   inflating: meta-grasp/scene10012/8_depth.png
#   inflating: meta-grasp/scene10012/8_order.csv
#   inflating: meta-grasp/scene10012/8_rgb.png
#   inflating: meta-grasp/scene10013/3_camera_params.json
#   inflating: meta-grasp/scene10013/3_depth.png
#   inflating: meta-grasp/scene10013/3_order.csv
#   inflating: meta-grasp/scene10013/3_rgb.png
#   inflating: meta-grasp/scene10013/4_camera_params.json
#   inflating: meta-grasp/scene10013/4_depth.png
#   inflating: meta-grasp/scene10013/4_order.csv
#   inflating: meta-grasp/scene10013/4_rgb.png
#   inflating: meta-grasp/scene10013/5_camera_params.json
#   inflating: meta-grasp/scene10013/5_depth.png
#   inflating: meta-grasp/scene10013/5_order.csv
#   inflating: meta-grasp/scene10013/5_rgb.png
#   inflating: meta-grasp/scene10013/6_camera_params.json
#   inflating: meta-grasp/scene10013/6_depth.png
#   inflating: meta-grasp/scene10013/6_order.csv
#   inflating: meta-grasp/scene10013/6_rgb.png
#   inflating: meta-grasp/scene10013/7_camera_params.json
#   inflating: meta-grasp/scene10013/7_depth.png
#   inflating: meta-grasp/scene10013/7_order.csv
#   inflating: meta-grasp/scene10013/7_rgb.png
#   inflating: meta-grasp/scene10014/1_camera_params.json
#   inflating: meta-grasp/scene10014/1_depth.png
#   inflating: meta-grasp/scene10014/1_order.csv
#   inflating: meta-grasp/scene10014/1_rgb.png
#   inflating: meta-grasp/scene10014/4_camera_params.json
#   inflating: meta-grasp/scene10014/4_depth.png
#   inflating: meta-grasp/scene10014/4_order.csv
#   inflating: meta-grasp/scene10014/4_rgb.png
#   inflating: meta-grasp/scene10014/5_camera_params.json
#   inflating: meta-grasp/scene10014/5_depth.png
#   inflating: meta-grasp/scene10014/5_order.csv
#   inflating: meta-grasp/scene10014/5_rgb.png
#   inflating: meta-grasp/scene10015/5_camera_params.json
#   inflating: meta-grasp/scene10015/5_depth.png
#   inflating: meta-grasp/scene10015/5_order.csv
#   inflating: meta-grasp/scene10015/5_rgb.png
#   inflating: meta-grasp/scene10015/6_camera_params.json
#   inflating: meta-grasp/scene10015/6_depth.png
#   inflating: meta-grasp/scene10015/6_order.csv
#   inflating: meta-grasp/scene10015/6_rgb.png
#   inflating: meta-grasp/scene10015/7_camera_params.json
#   inflating: meta-grasp/scene10015/7_depth.png
#   inflating: meta-grasp/scene10015/7_order.csv
#   inflating: meta-grasp/scene10015/7_rgb.png
#   inflating: meta-grasp/scene10015/8_camera_params.json
#   inflating: meta-grasp/scene10015/8_depth.png
#   inflating: meta-grasp/scene10015/8_order.csv
#   inflating: meta-grasp/scene10015/8_rgb.png
#   inflating: meta-grasp/scene10016/0_camera_params.json
#   inflating: meta-grasp/scene10016/0_depth.png
#   inflating: meta-grasp/scene10016/0_order.csv
#   inflating: meta-grasp/scene10016/0_rgb.png
#   inflating: meta-grasp/scene10016/1_camera_params.json
#   inflating: meta-grasp/scene10016/1_depth.png
#   inflating: meta-grasp/scene10016/1_order.csv
#   inflating: meta-grasp/scene10016/1_rgb.png
#   inflating: meta-grasp/scene10016/2_camera_params.json
#   inflating: meta-grasp/scene10016/2_depth.png
#   inflating: meta-grasp/scene10016/2_order.csv
#   inflating: meta-grasp/scene10016/2_rgb.png
#   inflating: meta-grasp/scene10016/3_camera_params.json
#   inflating: meta-grasp/scene10016/3_depth.png
#   inflating: meta-grasp/scene10016/3_order.csv
#   inflating: meta-grasp/scene10016/3_rgb.png
#   inflating: meta-grasp/scene10016/6_camera_params.json
#   inflating: meta-grasp/scene10016/6_depth.png
#   inflating: meta-grasp/scene10016/6_order.csv
#   inflating: meta-grasp/scene10016/6_rgb.png
#   inflating: meta-grasp/scene10017/5_camera_params.json
#   inflating: meta-grasp/scene10017/5_depth.png
#   inflating: meta-grasp/scene10017/5_order.csv
#   inflating: meta-grasp/scene10017/5_rgb.png
#   inflating: meta-grasp/scene10017/6_camera_params.json
#   inflating: meta-grasp/scene10017/6_depth.png
#   inflating: meta-grasp/scene10017/6_order.csv
#   inflating: meta-grasp/scene10017/6_rgb.png
#   inflating: meta-grasp/scene10017/7_camera_params.json
#   inflating: meta-grasp/scene10017/7_depth.png
#   inflating: meta-grasp/scene10017/7_order.csv
#   inflating: meta-grasp/scene10017/7_rgb.png
#   inflating: meta-grasp/scene10017/8_camera_params.json
#   inflating: meta-grasp/scene10017/8_depth.png
#   inflating: meta-grasp/scene10017/8_order.csv
#   inflating: meta-grasp/scene10017/8_rgb.png
#   inflating: meta-grasp/scene10018/1_camera_params.json
#   inflating: meta-grasp/scene10018/1_depth.png
#   inflating: meta-grasp/scene10018/1_order.csv
#   inflating: meta-grasp/scene10018/1_rgb.png
#   inflating: meta-grasp/scene10018/2_camera_params.json
#   inflating: meta-grasp/scene10018/2_depth.png
#   inflating: meta-grasp/scene10018/2_order.csv
#   inflating: meta-grasp/scene10018/2_rgb.png
#   inflating: meta-grasp/scene10018/3_camera_params.json
#   inflating: meta-grasp/scene10018/3_depth.png
#   inflating: meta-grasp/scene10018/3_order.csv
#   inflating: meta-grasp/scene10018/3_rgb.png
#   inflating: meta-grasp/scene10018/4_camera_params.json
#   inflating: meta-grasp/scene10018/4_depth.png
#   inflating: meta-grasp/scene10018/4_order.csv
#   inflating: meta-grasp/scene10018/4_rgb.png
#   inflating: meta-grasp/scene10019/0_camera_params.json
#   inflating: meta-grasp/scene10019/0_depth.png
#   inflating: meta-grasp/scene10019/0_order.csv
#   inflating: meta-grasp/scene10019/0_rgb.png
#   inflating: meta-grasp/scene10019/2_camera_params.json
#   inflating: meta-grasp/scene10019/2_depth.png
#   inflating: meta-grasp/scene10019/2_order.csv
#   inflating: meta-grasp/scene10019/2_rgb.png
#   inflating: meta-grasp/scene10019/3_camera_params.json
#   inflating: meta-grasp/scene10019/3_depth.png
#   inflating: meta-grasp/scene10019/3_order.csv
#   inflating: meta-grasp/scene10019/3_rgb.png
#   inflating: meta-grasp/scene10019/6_camera_params.json
#   inflating: meta-grasp/scene10019/6_depth.png
#   inflating: meta-grasp/scene10019/6_order.csv
#   inflating: meta-grasp/scene10019/6_rgb.png
#   inflating: meta-grasp/scene10019/7_camera_params.json
#   inflating: meta-grasp/scene10019/7_depth.png
#   inflating: meta-grasp/scene10019/7_order.csv
#   inflating: meta-grasp/scene10019/7_rgb.png
#   inflating: meta-grasp/scene10019/8_camera_params.json
#   inflating: meta-grasp/scene10019/8_depth.png
#   inflating: meta-grasp/scene10019/8_order.csv
#   inflating: meta-grasp/scene10019/8_rgb.png
#   inflating: meta-grasp/scene10020/1_camera_params.json
#   inflating: meta-grasp/scene10020/1_depth.png
#   inflating: meta-grasp/scene10020/1_order.csv
#   inflating: meta-grasp/scene10020/1_rgb.png
#   inflating: meta-grasp/scene10020/2_camera_params.json
#   inflating: meta-grasp/scene10020/2_depth.png
#   inflating: meta-grasp/scene10020/2_order.csv
#   inflating: meta-grasp/scene10020/2_rgb.png
#   inflating: meta-grasp/scene10020/3_camera_params.json
#   inflating: meta-grasp/scene10020/3_depth.png
#   inflating: meta-grasp/scene10020/3_order.csv
#   inflating: meta-grasp/scene10020/3_rgb.png
#   inflating: meta-grasp/scene10021/2_camera_params.json
#   inflating: meta-grasp/scene10021/2_depth.png
#   inflating: meta-grasp/scene10021/2_order.csv
#   inflating: meta-grasp/scene10021/2_rgb.png
#   inflating: meta-grasp/scene10021/3_camera_params.json
#   inflating: meta-grasp/scene10021/3_depth.png
#   inflating: meta-grasp/scene10021/3_order.csv
#   inflating: meta-grasp/scene10021/3_rgb.png
#   inflating: meta-grasp/scene10021/4_camera_params.json
#   inflating: meta-grasp/scene10021/4_depth.png
#   inflating: meta-grasp/scene10021/4_order.csv
#   inflating: meta-grasp/scene10021/4_rgb.png
#   inflating: meta-grasp/scene10021/5_camera_params.json
#   inflating: meta-grasp/scene10021/5_depth.png
#   inflating: meta-grasp/scene10021/5_order.csv
#   inflating: meta-grasp/scene10021/5_rgb.png
#   inflating: meta-grasp/scene10021/6_camera_params.json
#   inflating: meta-grasp/scene10021/6_depth.png
#   inflating: meta-grasp/scene10021/6_order.csv
#   inflating: meta-grasp/scene10021/6_rgb.png
#   inflating: meta-grasp/scene10021/7_camera_params.json
#   inflating: meta-grasp/scene10021/7_depth.png
#   inflating: meta-grasp/scene10021/7_order.csv
#   inflating: meta-grasp/scene10021/7_rgb.png
#   inflating: meta-grasp/scene10021/8_camera_params.json
#   inflating: meta-grasp/scene10021/8_depth.png
#   inflating: meta-grasp/scene10021/8_order.csv
#   inflating: meta-grasp/scene10021/8_rgb.png
#   inflating: meta-grasp/scene10022/0_camera_params.json
#   inflating: meta-grasp/scene10022/0_depth.png
#   inflating: meta-grasp/scene10022/0_order.csv
#   inflating: meta-grasp/scene10022/0_rgb.png
#   inflating: meta-grasp/scene10022/2_camera_params.json
#   inflating: meta-grasp/scene10022/2_depth.png
#   inflating: meta-grasp/scene10022/2_order.csv
#   inflating: meta-grasp/scene10022/2_rgb.png
#   inflating: meta-grasp/scene10022/5_camera_params.json
#   inflating: meta-grasp/scene10022/5_depth.png
#   inflating: meta-grasp/scene10022/5_order.csv
#   inflating: meta-grasp/scene10022/5_rgb.png
#   inflating: meta-grasp/scene10022/6_camera_params.json
#   inflating: meta-grasp/scene10022/6_depth.png
#   inflating: meta-grasp/scene10022/6_order.csv
#   inflating: meta-grasp/scene10022/6_rgb.png
#   inflating: meta-grasp/scene10022/7_camera_params.json
#   inflating: meta-grasp/scene10022/7_depth.png
#   inflating: meta-grasp/scene10022/7_order.csv
#   inflating: meta-grasp/scene10022/7_rgb.png
#   inflating: meta-grasp/scene10023/2_camera_params.json
#   inflating: meta-grasp/scene10023/2_depth.png
#   inflating: meta-grasp/scene10023/2_order.csv
#   inflating: meta-grasp/scene10023/2_rgb.png
#   inflating: meta-grasp/scene10023/3_camera_params.json
#   inflating: meta-grasp/scene10023/3_depth.png
#   inflating: meta-grasp/scene10023/3_order.csv
#   inflating: meta-grasp/scene10023/3_rgb.png
#   inflating: meta-grasp/scene10024/1_camera_params.json
#   inflating: meta-grasp/scene10024/1_depth.png
#   inflating: meta-grasp/scene10024/1_order.csv
#   inflating: meta-grasp/scene10024/1_rgb.png
#   inflating: meta-grasp/scene10024/2_camera_params.json
#   inflating: meta-grasp/scene10024/2_depth.png
#   inflating: meta-grasp/scene10024/2_order.csv
#   inflating: meta-grasp/scene10024/2_rgb.png
#   inflating: meta-grasp/scene10024/3_camera_params.json
#   inflating: meta-grasp/scene10024/3_depth.png
#   inflating: meta-grasp/scene10024/3_order.csv
#   inflating: meta-grasp/scene10024/3_rgb.png
#   inflating: meta-grasp/scene10024/4_camera_params.json
#   inflating: meta-grasp/scene10024/4_depth.png
#   inflating: meta-grasp/scene10024/4_order.csv
#   inflating: meta-grasp/scene10024/4_rgb.png
#   inflating: meta-grasp/scene10024/5_camera_params.json
#   inflating: meta-grasp/scene10024/5_depth.png
#   inflating: meta-grasp/scene10024/5_order.csv
#   inflating: meta-grasp/scene10024/5_rgb.png
#   inflating: meta-grasp/scene10025/5_camera_params.json
#   inflating: meta-grasp/scene10025/5_depth.png
#   inflating: meta-grasp/scene10025/5_order.csv
#   inflating: meta-grasp/scene10025/5_rgb.png
#   inflating: meta-grasp/scene10025/6_camera_params.json
#   inflating: meta-grasp/scene10025/6_depth.png
#   inflating: meta-grasp/scene10025/6_order.csv
#   inflating: meta-grasp/scene10025/6_rgb.png
#   inflating: meta-grasp/scene10025/7_camera_params.json
#   inflating: meta-grasp/scene10025/7_depth.png
#   inflating: meta-grasp/scene10025/7_order.csv
#   inflating: meta-grasp/scene10025/7_rgb.png
#   inflating: meta-grasp/scene10025/8_camera_params.json
#   inflating: meta-grasp/scene10025/8_depth.png
#   inflating: meta-grasp/scene10025/8_order.csv
#   inflating: meta-grasp/scene10025/8_rgb.png
#   inflating: meta-grasp/scene10026/1_camera_params.json
#   inflating: meta-grasp/scene10026/1_depth.png
#   inflating: meta-grasp/scene10026/1_order.csv
#   inflating: meta-grasp/scene10026/1_rgb.png
#   inflating: meta-grasp/scene10026/2_camera_params.json
#   inflating: meta-grasp/scene10026/2_depth.png
#   inflating: meta-grasp/scene10026/2_order.csv
#   inflating: meta-grasp/scene10026/2_rgb.png
#   inflating: meta-grasp/scene10026/3_camera_params.json
#   inflating: meta-grasp/scene10026/3_depth.png
#   inflating: meta-grasp/scene10026/3_order.csv
#   inflating: meta-grasp/scene10026/3_rgb.png
#   inflating: meta-grasp/scene10026/8_camera_params.json
#   inflating: meta-grasp/scene10026/8_depth.png
#   inflating: meta-grasp/scene10026/8_order.csv
#   inflating: meta-grasp/scene10026/8_rgb.png
#   inflating: meta-grasp/scene10027/0_camera_params.json
#   inflating: meta-grasp/scene10027/0_depth.png
#   inflating: meta-grasp/scene10027/0_order.csv
#   inflating: meta-grasp/scene10027/0_rgb.png
#   inflating: meta-grasp/scene10027/3_camera_params.json
#   inflating: meta-grasp/scene10027/3_depth.png
#   inflating: meta-grasp/scene10027/3_order.csv
#   inflating: meta-grasp/scene10027/3_rgb.png
#   inflating: meta-grasp/scene10027/6_camera_params.json
#   inflating: meta-grasp/scene10027/6_depth.png
#   inflating: meta-grasp/scene10027/6_order.csv
#   inflating: meta-grasp/scene10027/6_rgb.png
#   inflating: meta-grasp/scene10027/7_camera_params.json
#   inflating: meta-grasp/scene10027/7_depth.png
#   inflating: meta-grasp/scene10027/7_order.csv
#   inflating: meta-grasp/scene10027/7_rgb.png
#   inflating: meta-grasp/scene10027/8_camera_params.json
#   inflating: meta-grasp/scene10027/8_depth.png
#   inflating: meta-grasp/scene10027/8_order.csv
#   inflating: meta-grasp/scene10027/8_rgb.png
#   inflating: meta-grasp/scene10028/0_camera_params.json
#   inflating: meta-grasp/scene10028/0_depth.png
#   inflating: meta-grasp/scene10028/0_order.csv
#   inflating: meta-grasp/scene10028/0_rgb.png
#   inflating: meta-grasp/scene10028/1_camera_params.json
#   inflating: meta-grasp/scene10028/1_depth.png
#   inflating: meta-grasp/scene10028/1_order.csv
#   inflating: meta-grasp/scene10028/1_rgb.png
#   inflating: meta-grasp/scene10028/4_camera_params.json
#   inflating: meta-grasp/scene10028/4_depth.png
#   inflating: meta-grasp/scene10028/4_order.csv
#   inflating: meta-grasp/scene10028/4_rgb.png
#   inflating: meta-grasp/scene10028/5_camera_params.json
#   inflating: meta-grasp/scene10028/5_depth.png
#   inflating: meta-grasp/scene10028/5_order.csv
#   inflating: meta-grasp/scene10028/5_rgb.png
#   inflating: meta-grasp/scene10028/8_camera_params.json
#   inflating: meta-grasp/scene10028/8_depth.png
#   inflating: meta-grasp/scene10028/8_order.csv
#   inflating: meta-grasp/scene10028/8_rgb.png
#   inflating: meta-grasp/scene10029/0_camera_params.json
#   inflating: meta-grasp/scene10029/0_depth.png
#   inflating: meta-grasp/scene10029/0_order.csv
#   inflating: meta-grasp/scene10029/0_rgb.png
#   inflating: meta-grasp/scene10029/1_camera_params.json
#   inflating: meta-grasp/scene10029/1_depth.png
#   inflating: meta-grasp/scene10029/1_order.csv
#   inflating: meta-grasp/scene10029/1_rgb.png
#   inflating: meta-grasp/scene10029/2_camera_params.json
#   inflating: meta-grasp/scene10029/2_depth.png
#   inflating: meta-grasp/scene10029/2_order.csv
#   inflating: meta-grasp/scene10029/2_rgb.png
#   inflating: meta-grasp/scene10029/5_camera_params.json
#   inflating: meta-grasp/scene10029/5_depth.png
#   inflating: meta-grasp/scene10029/5_order.csv
#   inflating: meta-grasp/scene10029/5_rgb.png
#   inflating: meta-grasp/scene10029/6_camera_params.json
#   inflating: meta-grasp/scene10029/6_depth.png
#   inflating: meta-grasp/scene10029/6_order.csv
#   inflating: meta-grasp/scene10029/6_rgb.png
#   inflating: meta-grasp/scene10030/1_camera_params.json
#   inflating: meta-grasp/scene10030/1_depth.png
#   inflating: meta-grasp/scene10030/1_order.csv
#   inflating: meta-grasp/scene10030/1_rgb.png
#   inflating: meta-grasp/scene10030/2_camera_params.json
#   inflating: meta-grasp/scene10030/2_depth.png
#   inflating: meta-grasp/scene10030/2_order.csv
#   inflating: meta-grasp/scene10030/2_rgb.png
#   inflating: meta-grasp/scene10030/3_camera_params.json
#   inflating: meta-grasp/scene10030/3_depth.png
#   inflating: meta-grasp/scene10030/3_order.csv
#   inflating: meta-grasp/scene10030/3_rgb.png
#   inflating: meta-grasp/scene10030/4_camera_params.json
#   inflating: meta-grasp/scene10030/4_depth.png
#   inflating: meta-grasp/scene10030/4_order.csv
#   inflating: meta-grasp/scene10030/4_rgb.png
#   inflating: meta-grasp/scene10031/1_camera_params.json
#   inflating: meta-grasp/scene10031/1_depth.png
#   inflating: meta-grasp/scene10031/1_order.csv
#   inflating: meta-grasp/scene10031/1_rgb.png
#   inflating: meta-grasp/scene10031/7_camera_params.json
#   inflating: meta-grasp/scene10031/7_depth.png
#   inflating: meta-grasp/scene10031/7_order.csv
#   inflating: meta-grasp/scene10031/7_rgb.png
#   inflating: meta-grasp/scene10031/8_camera_params.json
#   inflating: meta-grasp/scene10031/8_depth.png
#   inflating: meta-grasp/scene10031/8_order.csv
#   inflating: meta-grasp/scene10031/8_rgb.png
#   inflating: meta-grasp/scene10032/2_camera_params.json
#   inflating: meta-grasp/scene10032/2_depth.png
#   inflating: meta-grasp/scene10032/2_order.csv
#   inflating: meta-grasp/scene10032/2_rgb.png
#   inflating: meta-grasp/scene10032/3_camera_params.json
#   inflating: meta-grasp/scene10032/3_depth.png
#   inflating: meta-grasp/scene10032/3_order.csv
#   inflating: meta-grasp/scene10032/3_rgb.png
#   inflating: meta-grasp/scene10032/4_camera_params.json
#   inflating: meta-grasp/scene10032/4_depth.png
#   inflating: meta-grasp/scene10032/4_order.csv
#   inflating: meta-grasp/scene10032/4_rgb.png
#   inflating: meta-grasp/scene10033/2_camera_params.json
#   inflating: meta-grasp/scene10033/2_depth.png
#   inflating: meta-grasp/scene10033/2_order.csv
#   inflating: meta-grasp/scene10033/2_rgb.png
#   inflating: meta-grasp/scene10033/3_camera_params.json
#   inflating: meta-grasp/scene10033/3_depth.png
#   inflating: meta-grasp/scene10033/3_order.csv
#   inflating: meta-grasp/scene10033/3_rgb.png
#   inflating: meta-grasp/scene10033/4_camera_params.json
#   inflating: meta-grasp/scene10033/4_depth.png
#   inflating: meta-grasp/scene10033/4_order.csv
#   inflating: meta-grasp/scene10033/4_rgb.png
#   inflating: meta-grasp/scene10033/5_camera_params.json
#   inflating: meta-grasp/scene10033/5_depth.png
#   inflating: meta-grasp/scene10033/5_order.csv
#   inflating: meta-grasp/scene10033/5_rgb.png
#   inflating: meta-grasp/scene10034/5_camera_params.json
#   inflating: meta-grasp/scene10034/5_depth.png
#   inflating: meta-grasp/scene10034/5_order.csv
#   inflating: meta-grasp/scene10034/5_rgb.png
#   inflating: meta-grasp/scene10034/6_camera_params.json
#   inflating: meta-grasp/scene10034/6_depth.png
#   inflating: meta-grasp/scene10034/6_order.csv
#   inflating: meta-grasp/scene10034/6_rgb.png
#   inflating: meta-grasp/scene10034/7_camera_params.json
#   inflating: meta-grasp/scene10034/7_depth.png
#   inflating: meta-grasp/scene10034/7_order.csv
#   inflating: meta-grasp/scene10034/7_rgb.png
#   inflating: meta-grasp/scene10035/0_camera_params.json
#   inflating: meta-grasp/scene10035/0_depth.png
#   inflating: meta-grasp/scene10035/0_order.csv
#   inflating: meta-grasp/scene10035/0_rgb.png
#   inflating: meta-grasp/scene10035/1_camera_params.json
#   inflating: meta-grasp/scene10035/1_depth.png
#   inflating: meta-grasp/scene10035/1_order.csv
#   inflating: meta-grasp/scene10035/1_rgb.png
#   inflating: meta-grasp/scene10035/4_camera_params.json
#   inflating: meta-grasp/scene10035/4_depth.png
#   inflating: meta-grasp/scene10035/4_order.csv
#   inflating: meta-grasp/scene10035/4_rgb.png
#   inflating: meta-grasp/scene10035/5_camera_params.json
#   inflating: meta-grasp/scene10035/5_depth.png
#   inflating: meta-grasp/scene10035/5_order.csv
#   inflating: meta-grasp/scene10035/5_rgb.png
#   inflating: meta-grasp/scene10035/8_camera_params.json
#   inflating: meta-grasp/scene10035/8_depth.png
#   inflating: meta-grasp/scene10035/8_order.csv
#   inflating: meta-grasp/scene10035/8_rgb.png
#   inflating: meta-grasp/scene10036/6_camera_params.json
#   inflating: meta-grasp/scene10036/6_depth.png
#   inflating: meta-grasp/scene10036/6_order.csv
#   inflating: meta-grasp/scene10036/6_rgb.png
#   inflating: meta-grasp/scene10036/7_camera_params.json
#   inflating: meta-grasp/scene10036/7_depth.png
#   inflating: meta-grasp/scene10036/7_order.csv
#   inflating: meta-grasp/scene10036/7_rgb.png
#   inflating: meta-grasp/scene10036/8_camera_params.json
#   inflating: meta-grasp/scene10036/8_depth.png
#   inflating: meta-grasp/scene10036/8_order.csv
#   inflating: meta-grasp/scene10036/8_rgb.png
#   inflating: meta-grasp/scene10037/0_camera_params.json
#   inflating: meta-grasp/scene10037/0_depth.png
#   inflating: meta-grasp/scene10037/0_order.csv
#   inflating: meta-grasp/scene10037/0_rgb.png
#   inflating: meta-grasp/scene10037/4_camera_params.json
#   inflating: meta-grasp/scene10037/4_depth.png
#   inflating: meta-grasp/scene10037/4_order.csv
#   inflating: meta-grasp/scene10037/4_rgb.png
#   inflating: meta-grasp/scene10037/5_camera_params.json
#   inflating: meta-grasp/scene10037/5_depth.png
#   inflating: meta-grasp/scene10037/5_order.csv
#   inflating: meta-grasp/scene10037/5_rgb.png
#   inflating: meta-grasp/scene10037/7_camera_params.json
#   inflating: meta-grasp/scene10037/7_depth.png
#   inflating: meta-grasp/scene10037/7_order.csv
#   inflating: meta-grasp/scene10037/7_rgb.png
#   inflating: meta-grasp/scene10037/8_camera_params.json
#   inflating: meta-grasp/scene10037/8_depth.png
#   inflating: meta-grasp/scene10037/8_order.csv
#   inflating: meta-grasp/scene10037/8_rgb.png
#   inflating: meta-grasp/scene10038/0_camera_params.json
#   inflating: meta-grasp/scene10038/0_depth.png
#   inflating: meta-grasp/scene10038/0_order.csv
#   inflating: meta-grasp/scene10038/0_rgb.png
#   inflating: meta-grasp/scene10038/3_camera_params.json
#   inflating: meta-grasp/scene10038/3_depth.png
#   inflating: meta-grasp/scene10038/3_order.csv
#   inflating: meta-grasp/scene10038/3_rgb.png
#   inflating: meta-grasp/scene10038/4_camera_params.json
#   inflating: meta-grasp/scene10038/4_depth.png
#   inflating: meta-grasp/scene10038/4_order.csv
#   inflating: meta-grasp/scene10038/4_rgb.png
#   inflating: meta-grasp/scene10038/7_camera_params.json
#   inflating: meta-grasp/scene10038/7_depth.png
#   inflating: meta-grasp/scene10038/7_order.csv
#   inflating: meta-grasp/scene10038/7_rgb.png
#   inflating: meta-grasp/scene10038/8_camera_params.json
#   inflating: meta-grasp/scene10038/8_depth.png
#   inflating: meta-grasp/scene10038/8_order.csv
#   inflating: meta-grasp/scene10038/8_rgb.png
#   inflating: meta-grasp/scene10039/0_camera_params.json
#   inflating: meta-grasp/scene10039/0_depth.png
#   inflating: meta-grasp/scene10039/0_order.csv
#   inflating: meta-grasp/scene10039/0_rgb.png
#   inflating: meta-grasp/scene10039/1_camera_params.json
#   inflating: meta-grasp/scene10039/1_depth.png
#   inflating: meta-grasp/scene10039/1_order.csv
#   inflating: meta-grasp/scene10039/1_rgb.png
#   inflating: meta-grasp/scene10039/4_camera_params.json
#   inflating: meta-grasp/scene10039/4_depth.png
#   inflating: meta-grasp/scene10039/4_order.csv
#   inflating: meta-grasp/scene10039/4_rgb.png
#   inflating: meta-grasp/scene10039/7_camera_params.json
#   inflating: meta-grasp/scene10039/7_depth.png
#   inflating: meta-grasp/scene10039/7_order.csv
#   inflating: meta-grasp/scene10039/7_rgb.png
#   inflating: meta-grasp/scene10039/8_camera_params.json
#   inflating: meta-grasp/scene10039/8_depth.png
#   inflating: meta-grasp/scene10039/8_order.csv
#   inflating: meta-grasp/scene10039/8_rgb.png
#   inflating: meta-grasp/scene10040/1_camera_params.json
#   inflating: meta-grasp/scene10040/1_depth.png
#   inflating: meta-grasp/scene10040/1_order.csv
#   inflating: meta-grasp/scene10040/1_rgb.png
#   inflating: meta-grasp/scene10040/2_camera_params.json
#   inflating: meta-grasp/scene10040/2_depth.png
#   inflating: meta-grasp/scene10040/2_order.csv
#   inflating: meta-grasp/scene10040/2_rgb.png
#   inflating: meta-grasp/scene10040/6_camera_params.json
#   inflating: meta-grasp/scene10040/6_depth.png
#   inflating: meta-grasp/scene10040/6_order.csv
#   inflating: meta-grasp/scene10040/6_rgb.png
#   inflating: meta-grasp/scene10040/7_camera_params.json
#   inflating: meta-grasp/scene10040/7_depth.png
#   inflating: meta-grasp/scene10040/7_order.csv
#   inflating: meta-grasp/scene10040/7_rgb.png
# ...
#   inflating: meta-grasp/scene9990/8_camera_params.json
#   inflating: meta-grasp/scene9990/8_depth.png
#   inflating: meta-grasp/scene9990/8_order.csv
#   inflating: meta-grasp/scene9990/8_rgb.png
#   inflating: meta-grasp/scene9991/0_camera_params.json
#   inflating: meta-grasp/scene9991/0_depth.png
#   inflating: meta-grasp/scene9991/0_order.csv
#   inflating: meta-grasp/scene9991/0_rgb.png
#   inflating: meta-grasp/scene9991/1_camera_params.json
#   inflating: meta-grasp/scene9991/1_depth.png
#   inflating: meta-grasp/scene9991/1_order.csv
#   inflating: meta-grasp/scene9991/1_rgb.png
#   inflating: meta-grasp/scene9991/2_camera_params.json
#   inflating: meta-grasp/scene9991/2_depth.png
#   inflating: meta-grasp/scene9991/2_order.csv
#   inflating: meta-grasp/scene9991/2_rgb.png
#   inflating: meta-grasp/scene9991/3_camera_params.json
#   inflating: meta-grasp/scene9991/3_depth.png
#   inflating: meta-grasp/scene9991/3_order.csv
#   inflating: meta-grasp/scene9991/3_rgb.png
#   inflating: meta-grasp/scene9991/4_camera_params.json
#   inflating: meta-grasp/scene9991/4_depth.png
#   inflating: meta-grasp/scene9991/4_order.csv
#   inflating: meta-grasp/scene9991/4_rgb.png
#   inflating: meta-grasp/scene9991/5_camera_params.json
#   inflating: meta-grasp/scene9991/5_depth.png
#   inflating: meta-grasp/scene9991/5_order.csv
#   inflating: meta-grasp/scene9991/5_rgb.png
#   inflating: meta-grasp/scene9991/6_camera_params.json
#   inflating: meta-grasp/scene9991/6_depth.png
#   inflating: meta-grasp/scene9991/6_order.csv
#   inflating: meta-grasp/scene9991/6_rgb.png
#   inflating: meta-grasp/scene9991/7_camera_params.json
#   inflating: meta-grasp/scene9991/7_depth.png
#   inflating: meta-grasp/scene9991/7_order.csv
#   inflating: meta-grasp/scene9991/7_rgb.png
#   inflating: meta-grasp/scene9991/8_camera_params.json
#   inflating: meta-grasp/scene9991/8_depth.png
#   inflating: meta-grasp/scene9991/8_order.csv
#   inflating: meta-grasp/scene9991/8_rgb.png
#   inflating: meta-grasp/scene9992/0_camera_params.json
#   inflating: meta-grasp/scene9992/0_depth.png
#   inflating: meta-grasp/scene9992/0_order.csv
#   inflating: meta-grasp/scene9992/0_rgb.png
#   inflating: meta-grasp/scene9992/1_camera_params.json
#   inflating: meta-grasp/scene9992/1_depth.png
#   inflating: meta-grasp/scene9992/1_order.csv
#   inflating: meta-grasp/scene9992/1_rgb.png
#   inflating: meta-grasp/scene9992/2_camera_params.json
#   inflating: meta-grasp/scene9992/2_depth.png
#   inflating: meta-grasp/scene9992/2_order.csv
#   inflating: meta-grasp/scene9992/2_rgb.png
#   inflating: meta-grasp/scene9992/3_camera_params.json
#   inflating: meta-grasp/scene9992/3_depth.png
#   inflating: meta-grasp/scene9992/3_order.csv
#   inflating: meta-grasp/scene9992/3_rgb.png
#   inflating: meta-grasp/scene9992/4_camera_params.json
#   inflating: meta-grasp/scene9992/4_depth.png
#   inflating: meta-grasp/scene9992/4_order.csv
#   inflating: meta-grasp/scene9992/4_rgb.png
#   inflating: meta-grasp/scene9992/5_camera_params.json
#   inflating: meta-grasp/scene9992/5_depth.png
#   inflating: meta-grasp/scene9992/5_order.csv
#   inflating: meta-grasp/scene9992/5_rgb.png
#   inflating: meta-grasp/scene9992/6_camera_params.json
#   inflating: meta-grasp/scene9992/6_depth.png
#   inflating: meta-grasp/scene9992/6_order.csv
#   inflating: meta-grasp/scene9992/6_rgb.png
#   inflating: meta-grasp/scene9992/7_camera_params.json
#   inflating: meta-grasp/scene9992/7_depth.png
#   inflating: meta-grasp/scene9992/7_order.csv
#   inflating: meta-grasp/scene9992/7_rgb.png
#   inflating: meta-grasp/scene9992/8_camera_params.json
#   inflating: meta-grasp/scene9992/8_depth.png
#   inflating: meta-grasp/scene9992/8_order.csv
#   inflating: meta-grasp/scene9992/8_rgb.png
#   inflating: meta-grasp/scene9993/1_camera_params.json
#   inflating: meta-grasp/scene9993/1_depth.png
#   inflating: meta-grasp/scene9993/1_order.csv
#   inflating: meta-grasp/scene9993/1_rgb.png
#   inflating: meta-grasp/scene9993/2_camera_params.json
#   inflating: meta-grasp/scene9993/2_depth.png
#   inflating: meta-grasp/scene9993/2_order.csv
#   inflating: meta-grasp/scene9993/2_rgb.png
#   inflating: meta-grasp/scene9993/3_camera_params.json
#   inflating: meta-grasp/scene9993/3_depth.png
#   inflating: meta-grasp/scene9993/3_order.csv
#   inflating: meta-grasp/scene9993/3_rgb.png
#   inflating: meta-grasp/scene9993/4_camera_params.json
#   inflating: meta-grasp/scene9993/4_depth.png
#   inflating: meta-grasp/scene9993/4_order.csv
#   inflating: meta-grasp/scene9993/4_rgb.png
#   inflating: meta-grasp/scene9993/5_camera_params.json
#   inflating: meta-grasp/scene9993/5_depth.png
#   inflating: meta-grasp/scene9993/5_order.csv
#   inflating: meta-grasp/scene9993/5_rgb.png
#   inflating: meta-grasp/scene9993/6_camera_params.json
#   inflating: meta-grasp/scene9993/6_depth.png
#   inflating: meta-grasp/scene9993/6_order.csv
#   inflating: meta-grasp/scene9993/6_rgb.png
#   inflating: meta-grasp/scene9993/7_camera_params.json
#   inflating: meta-grasp/scene9993/7_depth.png
#   inflating: meta-grasp/scene9993/7_order.csv
#   inflating: meta-grasp/scene9993/7_rgb.png
#   inflating: meta-grasp/scene9993/8_camera_params.json
#   inflating: meta-grasp/scene9993/8_depth.png
#   inflating: meta-grasp/scene9993/8_order.csv
#   inflating: meta-grasp/scene9993/8_rgb.png
#   inflating: meta-grasp/scene9994/0_camera_params.json
#   inflating: meta-grasp/scene9994/0_depth.png
#   inflating: meta-grasp/scene9994/0_order.csv
#   inflating: meta-grasp/scene9994/0_rgb.png
#   inflating: meta-grasp/scene9994/1_camera_params.json
#   inflating: meta-grasp/scene9994/1_depth.png
#   inflating: meta-grasp/scene9994/1_order.csv
#   inflating: meta-grasp/scene9994/1_rgb.png
#   inflating: meta-grasp/scene9994/2_camera_params.json
#   inflating: meta-grasp/scene9994/2_depth.png
#   inflating: meta-grasp/scene9994/2_order.csv
#   inflating: meta-grasp/scene9994/2_rgb.png
#   inflating: meta-grasp/scene9994/3_camera_params.json
#   inflating: meta-grasp/scene9994/3_depth.png
#   inflating: meta-grasp/scene9994/3_order.csv
#   inflating: meta-grasp/scene9994/3_rgb.png
#   inflating: meta-grasp/scene9994/4_camera_params.json
#   inflating: meta-grasp/scene9994/4_depth.png
#   inflating: meta-grasp/scene9994/4_order.csv
#   inflating: meta-grasp/scene9994/4_rgb.png
#   inflating: meta-grasp/scene9994/5_camera_params.json
#   inflating: meta-grasp/scene9994/5_depth.png
#   inflating: meta-grasp/scene9994/5_order.csv
#   inflating: meta-grasp/scene9994/5_rgb.png
#   inflating: meta-grasp/scene9994/6_camera_params.json
#   inflating: meta-grasp/scene9994/6_depth.png
#   inflating: meta-grasp/scene9994/6_order.csv
#   inflating: meta-grasp/scene9994/6_rgb.png
#   inflating: meta-grasp/scene9994/7_camera_params.json
#   inflating: meta-grasp/scene9994/7_depth.png
#   inflating: meta-grasp/scene9994/7_order.csv
#   inflating: meta-grasp/scene9994/7_rgb.png
#   inflating: meta-grasp/scene9994/8_camera_params.json
#   inflating: meta-grasp/scene9994/8_depth.png
#   inflating: meta-grasp/scene9994/8_order.csv
#   inflating: meta-grasp/scene9994/8_rgb.png
#   inflating: meta-grasp/scene9995/0_camera_params.json
#   inflating: meta-grasp/scene9995/0_depth.png
#   inflating: meta-grasp/scene9995/0_order.csv
#   inflating: meta-grasp/scene9995/0_rgb.png
#   inflating: meta-grasp/scene9995/1_camera_params.json
#   inflating: meta-grasp/scene9995/1_depth.png
#   inflating: meta-grasp/scene9995/1_order.csv
#   inflating: meta-grasp/scene9995/1_rgb.png
#   inflating: meta-grasp/scene9995/2_camera_params.json
#   inflating: meta-grasp/scene9995/2_depth.png
#   inflating: meta-grasp/scene9995/2_order.csv
#   inflating: meta-grasp/scene9995/2_rgb.png
#   inflating: meta-grasp/scene9995/3_camera_params.json
#   inflating: meta-grasp/scene9995/3_depth.png
#   inflating: meta-grasp/scene9995/3_order.csv
#   inflating: meta-grasp/scene9995/3_rgb.png
#   inflating: meta-grasp/scene9995/4_camera_params.json
#   inflating: meta-grasp/scene9995/4_depth.png
#   inflating: meta-grasp/scene9995/4_order.csv
#   inflating: meta-grasp/scene9995/4_rgb.png
#   inflating: meta-grasp/scene9995/5_camera_params.json
#   inflating: meta-grasp/scene9995/5_depth.png
#   inflating: meta-grasp/scene9995/5_order.csv
#   inflating: meta-grasp/scene9995/5_rgb.png
#   inflating: meta-grasp/scene9995/6_camera_params.json
#   inflating: meta-grasp/scene9995/6_depth.png
#   inflating: meta-grasp/scene9995/6_order.csv
#   inflating: meta-grasp/scene9995/6_rgb.png
#   inflating: meta-grasp/scene9995/7_camera_params.json
#   inflating: meta-grasp/scene9995/7_depth.png
#   inflating: meta-grasp/scene9995/7_order.csv
#   inflating: meta-grasp/scene9995/7_rgb.png
#   inflating: meta-grasp/scene9995/8_camera_params.json
#   inflating: meta-grasp/scene9995/8_depth.png
#   inflating: meta-grasp/scene9995/8_order.csv
#   inflating: meta-grasp/scene9995/8_rgb.png
#   inflating: meta-grasp/scene9996/0_camera_params.json
#   inflating: meta-grasp/scene9996/0_depth.png
#   inflating: meta-grasp/scene9996/0_order.csv
#   inflating: meta-grasp/scene9996/0_rgb.png
#   inflating: meta-grasp/scene9996/1_camera_params.json
#   inflating: meta-grasp/scene9996/1_depth.png
#   inflating: meta-grasp/scene9996/1_order.csv
#   inflating: meta-grasp/scene9996/1_rgb.png
#   inflating: meta-grasp/scene9996/2_camera_params.json
#   inflating: meta-grasp/scene9996/2_depth.png
#   inflating: meta-grasp/scene9996/2_order.csv
#   inflating: meta-grasp/scene9996/2_rgb.png
#   inflating: meta-grasp/scene9996/3_camera_params.json
#   inflating: meta-grasp/scene9996/3_depth.png
#   inflating: meta-grasp/scene9996/3_order.csv
#   inflating: meta-grasp/scene9996/3_rgb.png
#   inflating: meta-grasp/scene9996/4_camera_params.json
#   inflating: meta-grasp/scene9996/4_depth.png
#   inflating: meta-grasp/scene9996/4_order.csv
#   inflating: meta-grasp/scene9996/4_rgb.png
#   inflating: meta-grasp/scene9996/5_camera_params.json
#   inflating: meta-grasp/scene9996/5_depth.png
#   inflating: meta-grasp/scene9996/5_order.csv
#   inflating: meta-grasp/scene9996/5_rgb.png
#   inflating: meta-grasp/scene9996/6_camera_params.json
#   inflating: meta-grasp/scene9996/6_depth.png
#   inflating: meta-grasp/scene9996/6_order.csv
#   inflating: meta-grasp/scene9996/6_rgb.png
#   inflating: meta-grasp/scene9996/7_camera_params.json
#   inflating: meta-grasp/scene9996/7_depth.png
#   inflating: meta-grasp/scene9996/7_order.csv
#   inflating: meta-grasp/scene9996/7_rgb.png
#   inflating: meta-grasp/scene9996/8_camera_params.json
#   inflating: meta-grasp/scene9996/8_depth.png
#   inflating: meta-grasp/scene9996/8_order.csv
#   inflating: meta-grasp/scene9996/8_rgb.png
#   inflating: meta-grasp/scene9997/1_camera_params.json
#   inflating: meta-grasp/scene9997/1_depth.png
#   inflating: meta-grasp/scene9997/1_order.csv
#   inflating: meta-grasp/scene9997/1_rgb.png
#   inflating: meta-grasp/scene9997/2_camera_params.json
#   inflating: meta-grasp/scene9997/2_depth.png
#   inflating: meta-grasp/scene9997/2_order.csv
#   inflating: meta-grasp/scene9997/2_rgb.png
#   inflating: meta-grasp/scene9997/3_camera_params.json
#   inflating: meta-grasp/scene9997/3_depth.png
#   inflating: meta-grasp/scene9997/3_order.csv
#   inflating: meta-grasp/scene9997/3_rgb.png
#   inflating: meta-grasp/scene9997/4_camera_params.json
#   inflating: meta-grasp/scene9997/4_depth.png
#   inflating: meta-grasp/scene9997/4_order.csv
#   inflating: meta-grasp/scene9997/4_rgb.png
#   inflating: meta-grasp/scene9997/5_camera_params.json
#   inflating: meta-grasp/scene9997/5_depth.png
#   inflating: meta-grasp/scene9997/5_order.csv
#   inflating: meta-grasp/scene9997/5_rgb.png
#   inflating: meta-grasp/scene9997/6_camera_params.json
#   inflating: meta-grasp/scene9997/6_depth.png
#   inflating: meta-grasp/scene9997/6_order.csv
#   inflating: meta-grasp/scene9997/6_rgb.png
#   inflating: meta-grasp/scene9997/7_camera_params.json
#   inflating: meta-grasp/scene9997/7_depth.png
#   inflating: meta-grasp/scene9997/7_order.csv
#   inflating: meta-grasp/scene9997/7_rgb.png
#   inflating: meta-grasp/scene9997/8_camera_params.json
#   inflating: meta-grasp/scene9997/8_depth.png
#   inflating: meta-grasp/scene9997/8_order.csv
#   inflating: meta-grasp/scene9997/8_rgb.png
#   inflating: meta-grasp/scene9998/0_camera_params.json
#   inflating: meta-grasp/scene9998/0_depth.png
#   inflating: meta-grasp/scene9998/0_order.csv
#   inflating: meta-grasp/scene9998/0_rgb.png
#   inflating: meta-grasp/scene9998/1_camera_params.json
#   inflating: meta-grasp/scene9998/1_depth.png
#   inflating: meta-grasp/scene9998/1_order.csv
#   inflating: meta-grasp/scene9998/1_rgb.png
#   inflating: meta-grasp/scene9998/2_camera_params.json
#   inflating: meta-grasp/scene9998/2_depth.png
#   inflating: meta-grasp/scene9998/2_order.csv
#   inflating: meta-grasp/scene9998/2_rgb.png
#   inflating: meta-grasp/scene9998/3_camera_params.json
#   inflating: meta-grasp/scene9998/3_depth.png
#   inflating: meta-grasp/scene9998/3_order.csv
#   inflating: meta-grasp/scene9998/3_rgb.png
#   inflating: meta-grasp/scene9998/4_camera_params.json
#   inflating: meta-grasp/scene9998/4_depth.png
#   inflating: meta-grasp/scene9998/4_order.csv
#   inflating: meta-grasp/scene9998/4_rgb.png
#   inflating: meta-grasp/scene9998/5_camera_params.json
#   inflating: meta-grasp/scene9998/5_depth.png
#   inflating: meta-grasp/scene9998/5_order.csv
#   inflating: meta-grasp/scene9998/5_rgb.png
#   inflating: meta-grasp/scene9998/6_camera_params.json
#   inflating: meta-grasp/scene9998/6_depth.png
#   inflating: meta-grasp/scene9998/6_order.csv
#   inflating: meta-grasp/scene9998/6_rgb.png
#   inflating: meta-grasp/scene9998/7_camera_params.json
#   inflating: meta-grasp/scene9998/7_depth.png
#   inflating: meta-grasp/scene9998/7_order.csv
#   inflating: meta-grasp/scene9998/7_rgb.png
#   inflating: meta-grasp/scene9998/8_camera_params.json
#   inflating: meta-grasp/scene9998/8_depth.png
#   inflating: meta-grasp/scene9998/8_order.csv
#   inflating: meta-grasp/scene9998/8_rgb.png
#   inflating: meta-grasp/scene9999/0_camera_params.json
#   inflating: meta-grasp/scene9999/0_depth.png
#   inflating: meta-grasp/scene9999/0_order.csv
#   inflating: meta-grasp/scene9999/0_rgb.png
#   inflating: meta-grasp/scene9999/1_camera_params.json
#   inflating: meta-grasp/scene9999/1_depth.png
#   inflating: meta-grasp/scene9999/1_order.csv
#   inflating: meta-grasp/scene9999/1_rgb.png
#   inflating: meta-grasp/scene9999/2_camera_params.json
#   inflating: meta-grasp/scene9999/2_depth.png
#   inflating: meta-grasp/scene9999/2_order.csv
#   inflating: meta-grasp/scene9999/2_rgb.png
#   inflating: meta-grasp/scene9999/3_camera_params.json
#   inflating: meta-grasp/scene9999/3_depth.png
#   inflating: meta-grasp/scene9999/3_order.csv
#   inflating: meta-grasp/scene9999/3_rgb.png
#   inflating: meta-grasp/scene9999/4_camera_params.json
#   inflating: meta-grasp/scene9999/4_depth.png
#   inflating: meta-grasp/scene9999/4_order.csv
#   inflating: meta-grasp/scene9999/4_rgb.png
#   inflating: meta-grasp/scene9999/5_camera_params.json
#   inflating: meta-grasp/scene9999/5_depth.png
#   inflating: meta-grasp/scene9999/5_order.csv
#   inflating: meta-grasp/scene9999/5_rgb.png
#   inflating: meta-grasp/scene9999/6_camera_params.json
#   inflating: meta-grasp/scene9999/6_depth.png
#   inflating: meta-grasp/scene9999/6_order.csv
#   inflating: meta-grasp/scene9999/6_rgb.png
#   inflating: meta-grasp/scene9999/7_camera_params.json
#   inflating: meta-grasp/scene9999/7_depth.png
#   inflating: meta-grasp/scene9999/7_order.csv
#   inflating: meta-grasp/scene9999/7_rgb.png
#   inflating: meta-grasp/scene9999/8_camera_params.json
#   inflating: meta-grasp/scene9999/8_depth.png
#   inflating: meta-grasp/scene9999/8_order.csv
#   inflating: meta-grasp/scene9999/8_rgb.png
# mv: failed to access 'originalMetaGrasp/': No such file or directory

# %%
# need to run this cell
from pycocotools.coco import COCO
import skimage.io as io
import pylab

dataDir='/home/jeeten/MetaGrasp/originalMetaGrasp/'
dataType=''
annFile='/home/jeeten/MetaGrasp/originalMetaGrasp/difficulty-1-coco-label.json'.format(dataDir,dataType)

coco = COCO(annFile)
# Out:
# loading annotations into memory...
# Done (t=0.68s)
# creating index...
# index created!

# %%
# # could be run when done to visualize and see if the formating of the annotation json file is correct 
# imgIds = coco.getImgIds(catIds=1)
# imgIds
# # # # Run when done
# img = coco.loadImgs(imgIds[0])[0]
# I = io.imread('{}/{}/{}'.format(dataDir,dataType,img['file_name']))
# plt.axis('off')
# plt
# plt.imshow(I)
# plt.show()
# plt.imshow(I)
# plt.axis('off')
# annIds = coco.getAnnIds(imgIds=img['id'], iscrowd=None)
# anns = coco.loadAnns(annIds)
# coco.showAnns(anns, draw_bbox=1)

# %%
## fulljson used in the cell later
fulljson = open('/home/jeeten/MetaGrasp/originalMetaGrasp/difficulty-1-coco-label.json')
fullanno = json.load(fulljson)
fulljson.close()

# InstancesIDs is a list of list, with i index list being the list of the all the images containing the ith category object
InstancesIDs = []
for i in range(52):
    imgsList = coco.getImgIds(catIds=i)
    InstancesIDs.append(imgsList)

preauglist = []
for i in range(len(InstancesIDs)):
    if i in [0,2,11,40,42,47]:
        preauglist.append(InstancesIDs[i])
# preaugset contains all the imageIDs that needs to be part of new json (only containing imgs that contains at least contains one of the 6 catIDs)        
preaugset = set.union(*map(set,preauglist))

preaugdict = {
    "info": {},
    "licenses": [],
    "images": [],
    "annotations": [],
    "categories": []
}

catIDmap = {
    0: 1,
    2: 2,
    11: 3,
    40: 4,
    42: 5,
    47: 6
}
newcat = lambda x: catIDmap[x]

for i in range(len(fullanno['images'])):
    if fullanno['images'][i]['id'] in preaugset:
        preaugdict['images'].append(fullanno['images'][i])
        
for i in range(len(fullanno['annotations'])):
    if fullanno['annotations'][i]['image_id'] in preaugset and fullanno['annotations'][i]['category_id'] in [0,2,11,40,42,47]:
        preaugdict['annotations'].append(fullanno['annotations'][i])
        preaugdict['annotations'][-1]['category_id'] = newcat(preaugdict['annotations'][-1]['category_id'])

for i in range(len(fullanno['categories'])):
    if fullanno["categories"][i]['id'] in [0,2,11,40,42,47]:
        preaugdict['categories'].append(fullanno['categories'][i])
        preaugdict['categories'][-1]['id'] = newcat(preaugdict['categories'][-1]['id'])
        
        
out_file = open("preaugv1.json", "w")
json.dump(preaugdict, out_file, indent = 2)
out_file.close()

# %%
# ##temp code
# t1 = open("/home/jeeten/MetaGrasp/preaugv1.1.json")
# j1 = json.load(t1)
# t1.close()

# max = 0
# for dict in j1['images']:
#     if (max < dict['id']):
#         max = dict['id']
# print (max)

# %%
f = open('/home/jeeten/MetaGrasp/preaugv1.json')
anno = json.load(f)
f.close()

df = pd.DataFrame(columns = ['imgID', 'imgPath', 'dimgPath', 'labels', 'polygons', 'bboxes'])

for i in range(len(anno['images'])):
  tempDict = {'imgID': anno['images'][i]['id'],
            'imgPath':anno['images'][i]['file_name'],
            'dimgPath': anno['images'][i]['file_name'].replace('rgb', 'depth'),
            'labels':[],
            'layer': [],
            'polygons':[],
            'bboxes':[]}
  df = df.append(tempDict, ignore_index=True)

df.set_index('imgID', inplace=True)

# anno['annotations'][i] is a dict which looks like {'segmentation': [[749.........
for i in range(len(anno['annotations'])): 
  df.loc[anno['annotations'][i]['image_id']]['labels'].append(anno['annotations'][i]['category_id'])
  df.loc[anno['annotations'][i]['image_id']]['polygons'].append(anno['annotations'][i]['segmentation'])
  df.loc[anno['annotations'][i]['image_id']]['bboxes'].append(anno['annotations'][i]['bbox'])
  df.loc[anno['annotations'][i]['image_id']]['layer'].append(anno['annotations'][i]['layer'])

# %%
df.sort_index(inplace=True)
df.loc[23]
# Out:
# imgPath                        meta-grasp/scene2559/6_rgb.png
# dimgPath                     meta-grasp/scene2559/6_depth.png
# labels                                                 [3, 6]
# polygons    [[[525.0, 426.0, 524.0, 427.0, 520.0, 427.0, 5...
# bboxes      [[490.0, 426.0, 68.0, 328.0], [293.0, 570.0, 1...
# layer                                                  [0, 0]
# Name: 23, dtype: object

# %%
# defining transformations
D4_transforms = [
                A.HorizontalFlip(p=0.7),
                A.VerticalFlip(p=0.7),
                A.RandomRotate90(p=0.7),
                A.Transpose(p=0.7), 
                ]

Visual_transform = [
                    A.Blur (blur_limit=7, always_apply=False, p=0.2),
                    A.GaussianBlur (blur_limit=(3, 7), sigma_limit=0, always_apply=False, p=0.2),
                    #A.GaussNoise (var_limit=(10.0, 50.0), mean=0, per_channel=True, always_apply=False, p=0.2),
                    #A.ISONoise (color_shift=(0.01, 0.05), intensity=(1, 0.5), always_apply=False, p=0.2),
                    A.RandomBrightnessContrast (brightness_limit=0.2, contrast_limit=0.2, brightness_by_max=True, always_apply=False, p=0.4), 
                    ]

# %%
# defining functions to convert bitmask back to polygon
import rasterio
from rasterio import features
import shapely
from shapely.geometry import Point, Polygon

def mask_to_polygons_layer(mask):
    all_polygons = []
    for shape, value in features.shapes(mask.astype(np.int16), mask=(mask >0), transform=rasterio.Affine(1.0, 0, 0, 0, 1.0, 0)):
        all_polygons.append(shapely.geometry.shape(shape))

    all_polygons = shapely.geometry.MultiPolygon(all_polygons)
    if not all_polygons.is_valid:
        all_polygons = all_polygons.buffer(0)
        # Sometimes buffer() converts a simple Multipolygon to just a Polygon,
        # need to keep it a Multi throughout
        if all_polygons.type == 'Polygon':
            all_polygons = shapely.geometry.MultiPolygon([all_polygons])
    return all_polygons

# %%
dataDir='/home/jeeten/MetaGrasp/originalMetaGrasp/'
dataType=''
annFile='/home/jeeten/MetaGrasp/preaugv1.json'.format(dataDir,dataType)
coco = COCO(annFile)

# InstancesIDs is a list of list, where the ith element is a list of all the image ids which ccontains that catid
# Because now there is nothing know as catID = 0, and it starts from 1 till 6, you will see a lot of (i+1)s in code
InstancesIDs = []
for i in range(6):
  InstancesIDs.append(coco.getImgIds(catIds=i+1))


# numInstances is a list numbers, where the ith element is the number of occurences of that item in the dataset
numInstances = []
for i in range(6):
  numInstances.append(len(InstancesIDs[i]))


# not useful # catIds_aug is a list of numbers, where numbers are the catids that fulfill the augmentation eligiblity createria
catIds_aug = []
for i in range(6):
    catIds_aug.append(i+1)
# not useful# augmentable is a list of list, where each list has the image_ids that can be used for augmentation
augmentable = []
for catid in catIds_aug:
  augmentable.append(InstancesIDs[catid-1])
# not useful
aug_target = []
for catid in catIds_aug:
  aug_target.append(numInstances[0] - numInstances[catid-1])  

#aug_req is list of tuples, combining catIds_aug and augmentable and aug_target -- useful
aug_req=[(catIds_aug[i],augmentable[i],aug_target[i]) for i in range(0,len(augmentable))]
# Out:
# loading annotations into memory...
# Done (t=0.70s)
# creating index...
# index created!

# %%
len(InstancesIDs[0])
# Out:
# 2336

# %%
for i in range(len(aug_req)):
    if(aug_req[i][0] in [1,2,3,4,5,6]):
        print("the ClassID: " + str(aug_req[i][0]) + " has to be augmented by " + str(aug_req[i][2]))
# Out:
# the ClassID: 1 has to be augmented by 0
# the ClassID: 2 has to be augmented by 1813
# the ClassID: 3 has to be augmented by 1726
# the ClassID: 4 has to be augmented by 1830
# the ClassID: 5 has to be augmented by 1342
# the ClassID: 6 has to be augmented by 1759

# %%
def visualize_bbox(img, bbox, color=(255, 255, 0), thickness=2):  
    """Helper to add bboxes to images 
    Args:
        img : image as open-cv numpy array
        bbox : boxes as a list or numpy array in coco fromat [x_min, y_min, width, height]  
        color=(255, 255, 0): boxes color 
        thickness=2 : boxes line thickness
    """
    x_min, y_min, width, height = bbox
    x_min, y_min, width, height = int(x_min), int(y_min), int(width), int(height)
    cv2.rectangle(img, (x_min, y_min), (x_min+width, y_min+height), color=color, thickness=thickness)
    return img


def plot_image_anns(image, d_image, masks, boxes=None):
    """Helper to plot images with bboxes and masks 
    Args:
        image: image as open-cv numpy array
        d_image: depth image as open-cv numpy array
        masks: list of binary masks 
        bbox : boxes as a list or numpy array
    """
    # glue binary masks together
    one_mask = np.zeros_like(masks[0]).astype(np.uint8)
    for i, mask in enumerate(masks):
        one_mask += (mask > 0).astype(np.uint8) * (len(masks)-i) #
      
    if boxes is not None:
        for box in boxes:
            image = visualize_bbox(image, box)
            
    # for binary masks we get one channel and need to convert to RGB for visualization
    mask_rgb = label2rgb(one_mask, bg_label=0)            
        
    f, ax = plt.subplots(1, 3, figsize=(16, 16))             
    ax[0].imshow(image)
    ax[0].set_title('Original image')
    ax[1].imshow(d_image)
    ax[1].set_title('Original depth image')     
    ax[2].imshow(mask_rgb, interpolation='nearest')
    ax[2].set_title('Original mask')
    f.tight_layout()
    plt.show() 


def plot_image_aug(image, image_aug, d_image, aug_d_image, masks, aug_masks, bboxes, aug_bboxes):
    """Helper to plot images with bboxes and masks and their augmented versions 
    Args:
        image, image_aug: image as open-cv numpy array, original and augmented
        masks, aug_masks:setof binary masks, original and augmented 
        bbox, aug_boxes : boxes as a list or numpy array, original and augmented       
    """
    # glue masks together
    one_mask = np.zeros_like(masks[0]).astype(np.uint8)
    for i, mask in enumerate(masks):
        one_mask += (mask > 0).astype(np.uint8) * (len(masks)-i)
    
    one_aug_mask = np.zeros_like(aug_masks[0]).astype(np.uint8)
    for i, augmask in enumerate(aug_masks):
        one_aug_mask += (augmask > 0).astype(np.uint8) * (len(masks)-i)
    
    for box in bboxes:
        image = visualize_bbox(image, box)
    for augbox in aug_bboxes:
        image_aug = visualize_bbox(image_aug, augbox)    
        
    # for binary masks we get one channel and need to convert to RGB for visualization
    mask_rgb = label2rgb(one_mask, bg_label=0)            
    mask_aug_rgb = label2rgb(one_aug_mask, bg_label=0) 
    
    f, ax = plt.subplots(3, 2, figsize=(16, 16))             
    ax[0, 0].imshow(image)
    ax[0, 0].set_title('Original image')        
    ax[0, 1].imshow(image_aug)
    ax[0, 1].set_title('Augmented image')     
    ax[1, 0].imshow(mask_rgb, interpolation='nearest')
    ax[1, 0].set_title('Original mask')
    ax[1, 1].imshow(mask_aug_rgb, interpolation='nearest')
    ax[1, 1].set_title('Augmented mask')
    ax[2, 0].imshow(d_image)
    ax[2, 0].set_title('Original depth image')
    ax[2, 1].imshow(aug_d_image)
    ax[2, 1].set_title('Augmented depth image')
    f.tight_layout()
    plt.show()

# %%
new_img_index = 5237#This Id is not used till now for images
new_anno_index = 9168#This Id is not used till now for annotation
location = ""

for i in range(len(aug_req)):
    for j in range(aug_req[i][2]):
        # taking input from a list of the augmentable list
        imgID = random.choice(aug_req[i][1])
        row = df.loc[imgID]
        
        # I am only augmenting for classID aug_req[i][0] 
        catID = row['labels'].index(aug_req[i][0])
        
        dir = 'originalMetaGrasp/'
        image = cv2.imread(dir + row['imgPath'], cv2.IMREAD_UNCHANGED)
        d_image = cv2.imread(dir + row['dimgPath'], cv2.IMREAD_UNCHANGED)
        
        bitmasks = []
        poly = row['polygons'][catID]
        bitmasks.append(polygons_to_bitmask(poly, 1200, 1200))
        
        bboxes = [row['bboxes'][catID]]
        labels = np.array([row['labels'][catID]])
        layer = np.array([row['layer'][catID]])


        # # applying the transformation
        bbox_params={'format':'coco', 'label_fields': ['category_id']}
        augsD4 = A.Compose(D4_transforms, additional_targets={'d_image': 'image'}, bbox_params=bbox_params, p=1)       
        augmentedD4 = augsD4(image=image, d_image=d_image, masks=bitmasks, bboxes=bboxes, category_id=labels)     
        augsV = A.Compose(Visual_transform, p=1) 
        augmentedV = augsV(image=augmentedD4['image'])


        #getting the results back from the transformation
        aug_image = augmentedV['image']
        aug_d_image = augmentedD4['d_image']
        aug_masks = augmentedD4['masks']
        aug_bboxes = augmentedD4['bboxes']
        aug_area = []
        for mask in aug_masks:
            aug_area.append(mask.sum())


        #putting the mask back into the coco format
        aug_segmentation = []
        for k in range(len(aug_masks)):
            poly_i = list(mask_to_polygons_layer(aug_masks[k]).geoms)
            segmentation_aug_i = []
            for l,poly in enumerate(poly_i):
                x = enumerate(poly.exterior.coords.xy[0])
                segmentation_aug_i.append([])
                for m,xcor in x:
                    segmentation_aug_i[l].append(xcor)
                    segmentation_aug_i[l].append(poly.exterior.coords.xy[1][m])  
            aug_segmentation.append(segmentation_aug_i)

        
        #putting things in folder and json!!!
        img_dict = {
                  "file_name": row['imgPath'][:-9]+str(new_img_index)+'_rgb.png',
                  "height": 1200,
                  "width": 1200,
                  "id": new_img_index,
                  "difficulty": 1
                   }
        cv2.imwrite('/home/jeeten/MetaGrasp/originalMetaGrasp/'+img_dict['file_name'], aug_image, [cv2.IMWRITE_PNG_COMPRESSION,5])           
        cv2.imwrite('/home/jeeten/MetaGrasp/originalMetaGrasp/'+img_dict['file_name'][0:-8]+'_depth.png', aug_d_image, [cv2.IMWRITE_PNG_COMPRESSION,5])
        anno['images'].append(img_dict) 
        location = '/home/jeeten/'+img_dict['file_name']


        for index_num in range(labels.shape[0]):
            anno_dict = {
                "segmentation": aug_segmentation[index_num],
                "area": aug_area[index_num].tolist(),
                "iscrowd": 0,
                "image_id": new_img_index,
                "bbox": list(aug_bboxes[index_num]),
                "category_id": labels[index_num].tolist(),
                "id": new_anno_index,
                "layer": layer[index_num].tolist(),
                "occlusion": 0,
                "total_covered_edge": 0,
                "separated": False
            }

            anno['annotations'].append(anno_dict)
            new_anno_index = new_anno_index + 1
        new_img_index = new_img_index + 1  
        
    
out_file = open("post_aug_complete_test.json", "w")
json.dump(anno, out_file, indent = 2, cls=NumpyEncoder)
out_file.close()

# %%
print(new_img_index)
print(new_anno_index)
location
# Out:
# 5243
# 17638
# ''

# %%
### Remember the entire dataset as of now only has one json file, that needs to be divided into 3 subsets

# %%
#usefull to change the json to a int values for bbox and segmentation
f = open('/home/jeeten/aug_train.json')
anno = json.load(f)
f.close()

for i in range(len(anno['annotations'])):
    seg_int = []
    for j in range(len(anno['annotations'][i]['segmentation'])):
        piece_seg = [int(x) for x in anno['annotations'][i]['segmentation'][j]]
        seg_int.append(piece_seg)
    int_bbox = [int(x) for x in anno['annotations'][i]['bbox']]
    anno['annotations'][i]['segmentation'] = seg_int
    anno['annotations'][i]['bbox'] = int_bbox
    
out_file = open("aug_train.json", "w")
json.dump(anno, out_file, cls=NumpyEncoder)
out_file.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1081/234022741.py in <module>
#       1 #usefull to change the json to a int values for bbox and segmentation
# ----> 2 f = open('/home/jeeten/aug_coco.json')
#       3 anno = json.load(f)
#       4 f.close()
#       5
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/jeeten/aug_coco.json'
