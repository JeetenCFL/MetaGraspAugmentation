# %%
import cv2
import json
import matplotlib.pyplot as plt
import matplotlib.image as mat_img
import numpy as np
import pandas as pd
import os
import csv
import pandas as pd
import random
import albumentations as A
from numpyencoder import NumpyEncoder
from skimage.color import label2rgb
from pandas.io.json import json_normalize
from detectron2.structures import polygons_to_bitmask
# %matplotlib inline



# could be run when done to test 
from pycocotools.coco import COCO
import skimage.io as io
import pylab

dataDir='/home/jeeten/MetaGrasp/MetaGraspV2/'
dataType=''
annFile='/home/jeeten/MetaGrasp/MetaGraspV2/trainV2.json'.format(dataDir,dataType)

coco = COCO(annFile)



# Run when done
img = coco.loadImgs(6706)[0]#3981 is the image ID
I = io.imread('{}/{}/{}'.format(dataDir,dataType,img['file_name']))
plt.axis('off')
plt
plt.imshow(I)
plt.show()
plt.imshow(I)
plt.axis('off')
annIds = coco.getAnnIds(imgIds=img['id'], iscrowd=None)
anns = coco.loadAnns(annIds)
coco.showAnns(anns, draw_bbox=1)
# Out:
# loading annotations into memory...
# Done (t=1.33s)
# creating index...
# index created!
